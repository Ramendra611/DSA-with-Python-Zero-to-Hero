# %%
print("Hello i am learning python.")
# Out:
# Hello i am learning python.

# %%
print("I am learning to write code in my google colab!!!")
# Out:
# I am learning to write code in my google colab!!!
