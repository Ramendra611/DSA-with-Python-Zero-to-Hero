# %% [markdown]
# 1. Write a Python program to sum all the items in a list.
#
# 2. Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings.
# `a=['abc', 'xyz', 'aba', '1221','bhgsskknb','aa']`
#
# 3. Write a Python program to remove duplicates from a list.
#
# 4. Write a Python program to check if all dictionaries in a list are empty or not.
#
# 5. Write a Python program to find the list in a list of lists whose sum of elements is the highest
#   `num = [[1,2,3], [4,5,6], [10,11,12], [7,8,9]]`
#
# 6. write a program to make a new list after inserting a string `"customer"` at the begining of every elements in a list.
# `[100,123,345,567,789,890,98,876,543,678]`
#
# 7.Write a function that return the maximum and minimum of a given list
#
# 8. Write a function that returns the first_name and last_name when  user enters the full_name.
#
# 9. Write a function that prints the table of any number given.
#
# 10. Write a function that takes two lists and prints "yes" if they have at least one common member
# `[121,222,332,432,125], [125,236,457,678,779]`
