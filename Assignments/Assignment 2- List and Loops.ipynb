# %% [markdown]
# Assignment:
# 1. Print the sum of series of top 19 natural numbers using loop
# 2. Reverse the list of top 10 natural numbers using loop
# 3. Find the factorial of 5 using loop
# 4. Find all the numbers between 1000 and 2000 which are divisible by 7 and 5
# 5. Write a program to count the number of odd and even numbers¯ in the list [11,12,43,56,72,35,56,77,87,43]
# 6. Write a program to print the fibonacci series between 0-30
